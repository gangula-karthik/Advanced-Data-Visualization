# %% [markdown]
# ## Installing Packages

# %%
# %pip install numpy
# %pip install pandas
# %pip install geojson
# %pip install shapely
# %pip install geopandas
# %pip install beautifulsoup4

# %% [markdown]
# ## Importing Packages

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, MultiPoint, Polygon
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import numpy as np
import geojson
from shapely.wkt import loads
from shapely.geometry import mapping
from shapely.ops import unary_union

# %% [markdown]
# ## Loading the geojson file
#
# The challenging part of building the map is that there is no postal district geojson file which is publicly available. This means that the polygons for the districts will need to be custom drawn on the singapore map and exported as a geojson. I have tried this method but I found it extremely time consuming and not being a professional, the polygons drawn were not very accurate and high quality.
#
# Hence, one of the alternative approaches I had to consider was using the existing geojson maps available (there are geojson on planning areas) and then map it to the postal district. However, this proved to be challenging as well since certain districts were not covered in the planning areas like little india, macpherson/bradell, and more. As such I had to make use of a more detailed masterplan2019.
#
# We made use of the masterplan2019 with the subzone boundaries instead of the planning areas because it was more comprehensive and gave us a chance to cover all the districts unlike in planning area which missed out districts such as little india, macpherson/bradell, and more. Use subzone boundaries also allowed us to differentiate between those regions which belonged to multiple districts.
#
# I made use of a lookup table to map the planning areas to the districts based on the planning area names and subzone names as well but there were a lot which I was unable to map, for these I had to manually add them in by looking at the postal code and mapping it with the postal district.

# %%
file_path = './MasterPlan2019SubzoneBoundaryNoSeaGEOJSON.geojson'
singapore_map = gpd.read_file(file_path)

properties = singapore_map.columns
properties
# Out:
# Index(['Name', 'Description', 'geometry'], dtype='object')

# %%
postal_df = pd.read_json("./singapore_postals.json")
print(postal_df.iloc[1].postals)

postal_mapping = []
for entry in postal_df['postals']:
    district = entry['district']
    location = entry['locations']
    for sector in entry['sectors']:
        postal_mapping.append({'postal_sector': sector, 'postal_district': district, 'locations': location})

postal_mapping_df = pd.DataFrame(postal_mapping)
postal_mapping_df.head()
# Out:
# {'id': '02', 'district': '02', 'sectors': ['07', '08'], 'locations': ['Anson', 'Tanjong Pagar']}
#   postal_sector postal_district                                      locations
# 0            01              01  [Raffles Place, Cecil, Marina, People’s Park]
# 1            02              01  [Raffles Place, Cecil, Marina, People’s Park]
# 2            03              01  [Raffles Place, Cecil, Marina, People’s Park]
# 3            04              01  [Raffles Place, Cecil, Marina, People’s Park]
# 4            05              01  [Raffles Place, Cecil, Marina, People’s Park]

# %%
singapore_map
# Out:
#         Name                                        Description  \
# 0      kml_1  <center><table><tr><th colspan='2' align='cent...
# 1      kml_2  <center><table><tr><th colspan='2' align='cent...
# 2      kml_3  <center><table><tr><th colspan='2' align='cent...
# 3      kml_4  <center><table><tr><th colspan='2' align='cent...
# 4      kml_5  <center><table><tr><th colspan='2' align='cent...
# ..       ...                                                ...
# 327  kml_328  <center><table><tr><th colspan='2' align='cent...
# 328  kml_329  <center><table><tr><th colspan='2' align='cent...
# 329  kml_330  <center><table><tr><th colspan='2' align='cent...
# 330  kml_331  <center><table><tr><th colspan='2' align='cent...
# 331  kml_332  <center><table><tr><th colspan='2' align='cent...
#
#                                               geometry
# 0    POLYGON Z ((103.81 1.2824 0, 103.82 1.2804 0, ...
# 1    POLYGON Z ((103.82 1.2805 0, 103.82 1.2801 0, ...
# 2    POLYGON Z ((103.84 1.2851 0, 103.84 1.2849 0, ...
# 3    POLYGON Z ((103.85 1.2841 0, 103.85 1.2839 0, ...
# 4    POLYGON Z ((103.85 1.2862 0, 103.85 1.2862 0, ...
# ..                                                 ...
# 327  POLYGON Z ((103.84 1.3632 0, 103.84 1.3626 0, ...
# 328  POLYGON Z ((103.84 1.3709 0, 103.84 1.3709 0, ...
# 329  POLYGON Z ((103.85 1.3688 0, 103.85 1.3688 0, ...
# 330  POLYGON Z ((103.85 1.3452 0, 103.85 1.345 0, 1...
# 331  MULTIPOLYGON Z (((103.63 1.3069 0, 103.62 1.29...
#
# [332 rows x 3 columns]

# %%
def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table')
    data_dict = {}
    if table:
        rows = table.find_all('tr')
        for row in rows[1:]:  # Skip the header row
            columns = row.find_all(['th', 'td'])
            if len(columns) == 2:
                key = columns[0].get_text(strip=True)
                value = columns[1].get_text(strip=True)
                data_dict[key] = value
    return data_dict


singapore_map['parsed_data'] = singapore_map['Description'].apply(parse_html)

# Expand the parsed data into individual columns
parsed_df = pd.json_normalize(singapore_map['parsed_data'])
singapore_map = pd.concat([singapore_map, parsed_df], axis=1)

# Drop the original HTML column if no longer needed
singapore_map = singapore_map.drop(columns=['Description', 'parsed_data'])
singapore_map.head()
# Out:
#     Name                                           geometry SUBZONE_NO  \
# 0  kml_1  POLYGON Z ((103.81 1.2824 0, 103.82 1.2804 0, ...         12
# 1  kml_2  POLYGON Z ((103.82 1.2805 0, 103.82 1.2801 0, ...          2
# 2  kml_3  POLYGON Z ((103.84 1.2851 0, 103.84 1.2849 0, ...          3
# 3  kml_4  POLYGON Z ((103.85 1.2841 0, 103.85 1.2839 0, ...          4
# 4  kml_5  POLYGON Z ((103.85 1.2862 0, 103.85 1.2862 0, ...          5
#
#        SUBZONE_N SUBZONE_C CA_IND     PLN_AREA_N PLN_AREA_C        REGION_N  \
# 0     DEPOT ROAD    BMSZ12      N    BUKIT MERAH         BM  CENTRAL REGION
# 1    BUKIT MERAH    BMSZ02      N    BUKIT MERAH         BM  CENTRAL REGION
# 2      CHINATOWN    OTSZ03      Y         OUTRAM         OT  CENTRAL REGION
# 3        PHILLIP    DTSZ04      Y  DOWNTOWN CORE         DT  CENTRAL REGION
# 4  RAFFLES PLACE    DTSZ05      Y  DOWNTOWN CORE         DT  CENTRAL REGION
#
#   REGION_C           INC_CRC      FMEL_UPD_D
# 0       CR  C22DED671DE2A940  20191223152313
# 1       CR  085EF219A5A1AEAD  20191223152313
# 2       CR  EF2B9A91AF49E025  20191223152313
# 3       CR  615D4EDDEF809F8E  20191223152313
# 4       CR  72107B11807074F4  20191223152313

# %%
singapore_map.SUBZONE_N.unique()
# Out:
# array(['DEPOT ROAD', 'BUKIT MERAH', 'CHINATOWN', 'PHILLIP',
#        'RAFFLES PLACE', 'CHINA SQUARE', 'TIONG BAHRU', 'BAYFRONT SUBZONE',
#        'TIONG BAHRU STATION', 'CLIFFORD PIER', 'MARINA SOUTH', 'NICOLL',
#        'MARINA EAST', 'INSTITUTION HILL', 'ROBERTSON QUAY',
#        'JURONG ISLAND AND BUKOM', 'FORT CANNING', "PEARL'S HILL",
#        'BOAT QUAY', 'HENDERSON HILL', 'REDHILL', 'ALEXANDRA HILL',
#        'BUKIT HO SWEE', 'CLARKE QUAY', 'PASIR PANJANG 1', 'QUEENSWAY',
#        'MARINA EAST (MP)', 'SUDONG', 'SEMAKAU', 'SOUTHERN GROUP',
#        'SENTOSA', 'CITY TERMINALS', 'ANSON', 'STRAITS VIEW',
#        'MARITIME SQUARE', 'TELOK BLANGAH RISE', 'TANJONG PAGAR',
#        'EVERTON PARK', 'TELOK BLANGAH WAY', 'MAXWELL', 'CECIL',
#        'KAMPONG TIONG BAHRU', 'TELOK BLANGAH DRIVE', 'PASIR PANJANG 2',
#        'CENTRAL SUBZONE', 'SINGAPORE GENERAL HOSPITAL', 'BUGIS',
#        'VICTORIA', 'PATERSON', 'EAST COAST',
#        "NATIONAL UNIVERSITY OF S'PORE", 'ONE TREE HILL', 'COMMONWEALTH',
#        'DOVER', 'RIDOUT', 'CAIRNHILL', 'CLEMENTI WEST', "MONK'S HILL",
#        'SIGLAP', 'CLEMENTI WOODS', 'PIONEER SECTOR', 'PENJURU CRESCENT',
#        'ORANGE GROVE', 'KAMPONG BUGIS', 'KENT RIDGE', 'ALEXANDRA NORTH',
#        'TANGLIN HALT', 'MACKENZIE', 'SUNGEI ROAD', 'ONE NORTH',
#        'TANJONG RHU', 'KATONG', 'BOULEVARD', 'ISTANA NEGARA',
#        'LITTLE INDIA', 'GUL BASIN', 'MARINA CENTRE', 'BRAS BASAH',
#        'SOMERSET', 'BENCOOLEN', 'CHATSWORTH', 'KAMPONG GLAM', 'SELEGIE',
#        'MOUNT EMILY', 'ROCHOR CANAL', 'MARGARET DRIVE', 'OXLEY',
#        'CITY HALL', 'MEI CHIN', 'LEONIE HILL', 'PORT', 'DHOBY GHAUT',
#        'MACPHERSON', 'KIM KEAT', 'BEDOK NORTH', 'TOA PAYOH CENTRAL',
#        'JURONG GATEWAY', 'HOLLAND ROAD', 'KAMPONG UBI', 'SENNETT',
#        'POTONG PASIR', 'TUAS NORTH', 'PEI CHUN', 'BOON TECK', 'KIAN TECK',
#        'SAFTI', 'FARRER PARK', 'NEWTON CIRCUS', 'JURONG PORT',
#        'ANG MO KIO TOWN CENTRE', 'KEBUN BAHRU',
#        'SERANGOON NORTH IND ESTATE', 'TENGAH INDUSTRIAL ESTATE',
#        'SAMULUN', 'SHIPYARD', 'GHIM MOH', 'LAVENDER', 'FRANKEL',
#        'CLEMENTI NORTH', 'LEEDON PARK', 'GEYLANG EAST', 'TEBAN GARDENS',
#        'JURONG RIVER', 'GEYLANG BAHRU', 'GOODWOOD PARK', 'PANDAN',
#        'SINGAPORE POLYTECHNIC', 'CLEMENTI CENTRAL', 'KAMPONG JAVA',
#        'BOON KENG', 'KALLANG BAHRU', 'ULU PANDAN', 'FARRER COURT',
#        'NASSIM', 'WEST COAST', 'BAYSHORE', 'BENOI SECTOR', 'GUL CIRCLE',
#        'TYERSALL', 'MOULMEIN', 'LIU FANG', 'TANGLIN', 'MARINE PARADE',
#        'JOO KOON', 'KALLANG WAY', 'INTERNATIONAL BUSINESS PARK', 'TUKANG',
#        'CORONATION ROAD', 'KEMBANGAN', 'DUNEARN', 'SUNSET WAY',
#        'ANAK BUKIT', 'SWISS CLUB', 'XILIN', 'FABER', 'MALCOLM',
#        'BEDOK SOUTH', 'DEFU INDUSTRIAL PARK', 'CHANGI BAY',
#        'PAYA LEBAR EAST', 'HONG KAH NORTH', 'KOVAN', 'CHONG BOON',
#        'SERANGOON GARDEN', 'HOUGANG CENTRAL', 'LOYANG EAST', 'DAIRY FARM',
#        'PASIR RIS DRIVE', 'TAMPINES NORTH', 'CHENG SAN',
#        'SEMBAWANG HILLS', 'JELEBU', 'KEAT HONG', 'BENDEMEER', 'BALESTIER',
#        'TUAS PROMENADE', 'SERANGOON CENTRAL', 'BISHAN EAST',
#        'TAMPINES WEST', 'BRICKWORKS', 'SERANGOON NORTH', 'GUILIN',
#        'WENYA', 'NATURE RESERVE', 'TAMPINES EAST', 'LORONG AH SOO',
#        'FLORA DRIVE', 'HILLVIEW', 'TOH TUCK', 'MOUNT PLEASANT',
#        'HILLCREST', 'JOO SENG', 'CHIN BEE', 'LORONG 8 TOA PAYOH',
#        'TOH GUAN', 'SIMEI', 'BOON LAY PLACE', 'BUKIT BATOK EAST',
#        'BUKIT BATOK WEST', 'BUKIT BATOK CENTRAL', 'UPPER PAYA LEBAR',
#        'TAI SENG', 'TENGEH', 'YUHUA WEST', 'BRADDELL', 'BIDADARI',
#        'WOODLEIGH', 'TAMAN JURONG', 'LAKESIDE (LEISURE)',
#        'TOA PAYOH WEST', 'KAKI BUKIT', 'YUHUA EAST', 'BUKIT BATOK SOUTH',
#        'JURONG WEST CENTRAL', 'BEDOK RESERVOIR', 'LOWER SELETAR',
#        'NORTHSHORE', 'MANDAI ESTATE', 'YISHUN CENTRAL',
#        'PASIR RIS CENTRAL', 'GOMBAK', 'PAYA LEBAR NORTH', 'HOUGANG EAST',
#        'LORONG HALUS', 'KANGKAR', 'CHANGI WEST', 'HOLLAND DRIVE',
#        'HOUGANG WEST', 'PAYA LEBAR WEST', 'BANGKIT', 'LORONG HALUS NORTH',
#        'PENG SIANG', 'PASIR RIS WEST', 'YIO CHU KANG WEST',
#        'CHANGI POINT', 'SENGKANG TOWN CENTRE', 'ANCHORVALE',
#        'SENGKANG WEST', 'FERNVALE', 'PUNGGOL FIELD', 'YEW TEE',
#        'PASIR RIS WAFER FAB PARK', 'TRAFALGAR', 'TECK WHYE',
#        'CHOA CHU KANG CENTRAL', 'FAJAR', 'SENJA', 'SAUJANA',
#        'SELETAR HILLS', 'COMPASSVALE', 'YIO CHU KANG EAST',
#        'YIO CHU KANG', 'LOYANG WEST', 'TAGORE', 'PASIR RIS PARK',
#        'CHOA CHU KANG NORTH', 'RIVERVALE', 'YIO CHU KANG NORTH', 'YUNNAN',
#        'LORONG CHUAN', 'HONG KAH', 'SELETAR', 'PANG SUA',
#        'SELETAR AEROSPACE PARK', 'KHATIB', 'MANDAI WEST', 'CONEY ISLAND',
#        'YISHUN SOUTH', 'RESERVOIR VIEW', 'WOODLANDS EAST',
#        'SEMBAWANG CENTRAL', 'GREENWOOD PARK', 'SEMBAWANG EAST',
#        'SENOKO WEST', 'MATILDA', 'WATERWAY EAST', 'GALI BATU', 'CRAWFORD',
#        'TUAS BAY', 'TUAS VIEW', 'BAHAR', 'CLEANTECH',
#        'LAKESIDE (BUSINESS)', 'PARK', 'BRICKLAND', 'FOREST HILL',
#        'PLANTATION', 'GARDEN', 'AIRPORT ROAD', 'NORTH COAST',
#        'SPRINGLEAF', 'PUNGGOL TOWN CENTRE', 'PUNGGOL CANAL',
#        'CENTRAL WATER CATCHMENT', 'SEMBAWANG STRAITS', 'THE WHARVES',
#        'SENOKO NORTH', 'CHANGI AIRPORT', "PEOPLE'S PARK", 'MOUNTBATTEN',
#        'ALJUNIED', 'PULAU PUNGGOL TIMOR', 'TURF CLUB', 'WOODLANDS SOUTH',
#        'WOODGROVE', 'YISHUN EAST', 'MURAI', 'PULAU PUNGGOL BARAT',
#        'PULAU SELETAR', 'ADMIRALTY', 'LIM CHU KANG', 'SIMPANG NORTH',
#        'SENOKO SOUTH', 'SEMBAWANG NORTH', 'TANJONG IRAU', 'YISHUN WEST',
#        'WOODLANDS REGIONAL CENTRE', 'NORTH-EASTERN ISLANDS',
#        'SIMPANG SOUTH', 'NORTHLAND', 'MIDVIEW', 'WOODLANDS WEST',
#        'SEMBAWANG SPRINGS', 'KRANJI', 'PLAB', 'MANDAI EAST', 'NEE SOON',
#        'UPPER THOMSON', 'SHANGRI-LA', 'TOWNSVILLE', 'MARYMOUNT',
#        'TUAS VIEW EXTENSION'], dtype=object)

# %%
singapore_map.to_csv("sg_map_data.csv")

# %%
def find_postal_district(pln_area_n, subzone_n, mapping_df):
    for _, row in mapping_df.iterrows():
        # Check if PLN_AREA_N or SUBZONE_N matches any location in the mapping DataFrame
        if any(location.lower() in pln_area_n.lower() for location in row['locations']) or \
           any(location.lower() in subzone_n.lower() for location in row['locations']):
            return row['postal_district']
        # Debugging print statements
        print(f"PLN_AREA_N: {pln_area_n.lower()}, SUBZONE_N: {subzone_n.lower()}, Locations: {[location.lower() for location in row['locations']]}")
    return np.nan

# %%
singapore_map['postal_district'] = singapore_map.apply(
    lambda row: find_postal_district(row['PLN_AREA_N'], row['SUBZONE_N'], postal_mapping_df),
    axis=1
)

singapore_map.head()
# Out:
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['little india']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['little india']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['loyang', 'changi']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['loyang', 'changi']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['loyang', 'changi']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['seletar']
# PLN_AREA_N: bukit merah, SUBZONE_N: depot road, Locations: ['seletar']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['little india']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['little india']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['loyang', 'changi']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['loyang', 'changi']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['loyang', 'changi']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['jurong']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['seletar']
# PLN_AREA_N: bukit merah, SUBZONE_N: bukit merah, Locations: ['seletar']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['little india']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['little india']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['loyang', 'changi']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['loyang', 'changi']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['loyang', 'changi']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['seletar']
# PLN_AREA_N: outram, SUBZONE_N: chinatown, Locations: ['seletar']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['little india']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['little india']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['loyang', 'changi']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['loyang', 'changi']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['loyang', 'changi']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['seletar']
# PLN_AREA_N: downtown core, SUBZONE_N: phillip, Locations: ['seletar']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['little india']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['little india']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['geylang', 'eunos']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['loyang', 'changi']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['loyang', 'changi']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['loyang', 'changi']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['jurong']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['seletar']
# PLN_AREA_N: outram, SUBZONE_N: china square, Locations: ['seletar']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['little india']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['little india']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['geylang', 'eunos']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['loyang', 'changi']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['loyang', 'changi']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['loyang', 'changi']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['jurong']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['seletar']
# PLN_AREA_N: downtown core, SUBZONE_N: bayfront subzone, Locations: ['seletar']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bukit merah, SUBZONE_N: tiong bahru station, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: downtown core, SUBZONE_N: clifford pier, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# ...
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['geylang', 'eunos']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['geylang', 'eunos']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['geylang', 'eunos']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['geylang', 'eunos']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['loyang', 'changi']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['loyang', 'changi']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['loyang', 'changi']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: ang mo kio, SUBZONE_N: townsville, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['little india']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['little india']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['geylang', 'eunos']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['loyang', 'changi']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['loyang', 'changi']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['loyang', 'changi']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: bishan, SUBZONE_N: marymount, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['raffles place', 'cecil', 'marina', 'people’s park']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['anson', 'tanjong pagar']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['queenstown', 'tiong bahru']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['telok blangah', 'harbourfront']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['pasir panjang', 'hong leong garden', 'clementi new town']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['high street', 'beach road (part)']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['middle road', 'golden mile']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['little india']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['little india']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['orchard', 'cairnhill', 'river valley']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['ardmore', 'bukit timah', 'holland road', 'tanglin']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['watten estate', 'novena', 'thomson']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['balestier', 'toa payoh', 'serangoon']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['macpherson', 'braddell']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['geylang', 'eunos']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['geylang', 'eunos']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['geylang', 'eunos']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['geylang', 'eunos']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['katong', 'joo chiat', 'amber road']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['bedok', 'upper east coast', 'eastwood', 'kew drive']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['loyang', 'changi']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['loyang', 'changi']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['loyang', 'changi']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['tampines', 'pasir ris']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['serangoon garden', 'hougang', 'ponggol']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['bishan', 'ang mo kio']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['upper bukit timah', 'clementi park', 'ulu pandan']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['jurong']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['jurong']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['jurong']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['jurong']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['jurong']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['hillview', 'dairy farm', 'bukit panjang', 'choa chu kang']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['lim chu kang', 'tengah']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['kranji', 'woodgrove', 'woodlands']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['upper thomson', 'springleaf']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['yishun', 'sembawang']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['seletar']
# PLN_AREA_N: tuas, SUBZONE_N: tuas view extension, Locations: ['seletar']
#     Name                                           geometry SUBZONE_NO  \
# 0  kml_1  POLYGON Z ((103.81 1.2824 0, 103.82 1.2804 0, ...         12
# 1  kml_2  POLYGON Z ((103.82 1.2805 0, 103.82 1.2801 0, ...          2
# 2  kml_3  POLYGON Z ((103.84 1.2851 0, 103.84 1.2849 0, ...          3
# 3  kml_4  POLYGON Z ((103.85 1.2841 0, 103.85 1.2839 0, ...          4
# 4  kml_5  POLYGON Z ((103.85 1.2862 0, 103.85 1.2862 0, ...          5
#
#        SUBZONE_N SUBZONE_C CA_IND     PLN_AREA_N PLN_AREA_C        REGION_N  \
# 0     DEPOT ROAD    BMSZ12      N    BUKIT MERAH         BM  CENTRAL REGION
# 1    BUKIT MERAH    BMSZ02      N    BUKIT MERAH         BM  CENTRAL REGION
# 2      CHINATOWN    OTSZ03      Y         OUTRAM         OT  CENTRAL REGION
# 3        PHILLIP    DTSZ04      Y  DOWNTOWN CORE         DT  CENTRAL REGION
# 4  RAFFLES PLACE    DTSZ05      Y  DOWNTOWN CORE         DT  CENTRAL REGION
#
#   REGION_C           INC_CRC      FMEL_UPD_D postal_district
# 0       CR  C22DED671DE2A940  20191223152313             NaN
# 1       CR  085EF219A5A1AEAD  20191223152313             NaN
# 2       CR  EF2B9A91AF49E025  20191223152313             NaN
# 3       CR  615D4EDDEF809F8E  20191223152313             NaN
# 4       CR  72107B11807074F4  20191223152313              01

# %% [markdown]
# This is the result that I have achieved after performing the matching based on the lookup json table which I created after referencing from the URA website:
#
# https://www.ura.gov.sg/Corporate/-/media/Corporate/Property/PMI-Online/List_Of_Postal_Districts.pdf

# %%
singapore_map.postal_district.value_counts()
# Out:
# postal_district
# 22    35
# 12    19
# 03    18
# 27    17
# 20    14
# 10    12
# 18    11
# 25    10
# 19    10
# 09     9
# 16     8
# 24     7
# 17     6
# 11     6
# 01     6
# 14     5
# 28     5
# 04     3
# 02     2
# 13     1
# 08     1
# 15     1
# 26     1
# Name: count, dtype: int64

# %%
csv_file = "sg_map_data.csv"
df = pd.read_csv(csv_file)
df = df[['geometry', 'SUBZONE_N', 'PLN_AREA_N', 'postal_district']]
df.head()
# Out:
#                                             geometry        SUBZONE_N  \
# 0  POLYGON Z ((103.828545450459 1.45877524953475 ...        ADMIRALTY
# 1  POLYGON Z ((103.901327898145 1.35658812288024 ...     AIRPORT ROAD
# 2  POLYGON Z ((103.81444653879 1.28547429883476 0...   ALEXANDRA HILL
# 3  POLYGON Z ((103.817404504805 1.29433192068692 ...  ALEXANDRA NORTH
# 4  POLYGON Z ((103.891267385312 1.32131770982548 ...         ALJUNIED
#
#     PLN_AREA_N  postal_district
# 0    SEMBAWANG             27.0
# 1   PAYA LEBAR             14.0
# 2  BUKIT MERAH              NaN
# 3  BUKIT MERAH              NaN
# 4      GEYLANG             14.0

# %%
filtered_df = df

# Handle NaN values in postal_district
filtered_df['postal_district'] = filtered_df['postal_district'].fillna(
    "Unknown")

# Group by postal_district and merge polygons
merged_features = []
for postal_district, group in filtered_df.groupby('postal_district'):
    try:
        # Combine all geometries for the postal_district
        geometries = [loads(geom) for geom in group['geometry']]
        merged_geometry = unary_union(geometries)  # Merge polygons

        # Get other properties from the first row in the group
        subzone_n = group['SUBZONE_N'].iloc[0]
        pln_area_n = group['PLN_AREA_N'].iloc[0]

        # Create GeoJSON feature
        feature = geojson.Feature(
            geometry=mapping(merged_geometry),
            properties={
                "postal_district": postal_district,
                "SUBZONE_N": subzone_n,
                "PLN_AREA_N": pln_area_n
            }
        )
        merged_features.append(feature)
    except Exception as e:
        print(f"Skipping postal_district {postal_district} due to geometry error: {e}")

# Create GeoJSON FeatureCollection
feature_collection = geojson.FeatureCollection(merged_features)

# Save to a GeoJSON file
output_file = "merged_output.geojson"
with open(output_file, "w") as f:
    geojson.dump(feature_collection, f)

print(f"Merged GeoJSON file created: {output_file}")
# Out:
# Merged GeoJSON file created: merged_output.geojson

# %% [markdown]
# ## Converting to GEOJSON format
#
# The final step is to take the csv file and convert to geojson since the d3 chloropleth map takes that data in that format.

# %%
# Prepare GeoJSON features
features = []
for _, row in df.iterrows():
    # Convert WKT to GeoJSON geometry if necessary
    try:
        geometry = loads(row['geometry'])  # Assumes geometry is in WKT format
        geojson_geometry = mapping(geometry)
    except Exception as e:
        print(f"Skipping row due to geometry error: {e}")
        continue  # Skip rows with invalid geometry

    # Handle NaN values in postal_district
    postal_district = row['postal_district']
    if pd.isna(postal_district):  # Check if postal_district is NaN
        postal_district = "Unknown"  # Replace with a default value

    # Create GeoJSON feature
    feature = geojson.Feature(
        geometry=geojson_geometry,
        properties={
            "SUBZONE_N": row['SUBZONE_N'],
            "PLN_AREA_N": row['PLN_AREA_N'],
            "postal_district": postal_district
        }
    )
    features.append(feature)

# Create GeoJSON FeatureCollection
feature_collection = geojson.FeatureCollection(features)

# Save to a GeoJSON file
output_file = "output.geojson"
with open(output_file, "w") as f:
    geojson.dump(feature_collection, f)

print(f"GeoJSON file created: {output_file}")
# Out:
# GeoJSON file created: output.geojson
